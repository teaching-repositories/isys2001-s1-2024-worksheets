# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-borck/isys2001-worksheets/blob/main/number_guess_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Guess my Number

# %%
#@title
from google.colab import output
from os.path import exists
if not exists('number_guess.ipynb'):
  # !wget https://raw.githubusercontent.com/michael-borck/isys2001-worksheets/main/number_guess.ipynb
output.clear()
# %run number_guess.ipynb
