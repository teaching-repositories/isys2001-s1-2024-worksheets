# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-borck/isys2001-worksheets/blob/main/Copy_of_input_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Input Validation
#
# Input validation code verifies that user supplied data, such as text from the input() function, is formatted appropriately.
#
# * try/except
# * isdigit()
# * pyinputplus
#
# ## try/except

# %% [markdown]
# ## isdigit()

# %% [markdown]
# ## Module: pyinputs
